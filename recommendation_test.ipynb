# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

secrets_dict = {}

secret_file = open("spotify_creds.txt")

for line in secret_file:
	key, val = line.split(":")
	secrets_dict[key] = val[:-1]

print(secrets_dict.keys())

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=secrets_dict["Client ID"],
                                               client_secret=secrets_dict["Client Secret"],
                                               redirect_uri="https://localhost:8080/callback",
                                               scope="user-library-read"))
# Out:
# dict_keys(['Client ID', 'Client Secret'])

# %%
results = sp.current_user_saved_tracks(limit=50)
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# 0 White Lung  –  Kiss Me When I Bleed
# 1 Lanterns on the Lake  –  Through the Cellar Door
# 2 Elephant Tree  –  Circles
# 3 Kylesa  –  Vulture's Landing
# 4 Monolord  –  Rust
# 5 Paramore  –  Misery Business
# 6 The Weeknd  –  Blinding Lights
# 7 Wolf Alice  –  Beautifully Unconventional
# 8 Wolf Alice  –  Don’t Delete The Kisses
# 9 Tears For Fears  –  Shout
# 10 Dirty Dishes  –  Thank You Come Again
# 11 Cloud Nothings  –  Cut You
# 12 Land of Talk  –  Some Are Lakes
# 13 DILLY DALLY  –  Ballin' Chain
# 14 Speedy Ortiz  –  No Below
# 15 Soul Coughing  –  Screenwriter's Blues
# 16 Speedy Ortiz  –  Cash Cab
# 17 Citizen  –  Ring of Chain
# 18 Windhand  –  Grey Garden
# 19 Herbie Hancock  –  Cantaloupe Island - Remastered
# 20 Adriano Celentano  –  Prisencolinensinainciusol
# 21 STARSET  –  Monster
# 22 Hollywood Undead  –  California Dreaming
# 23 Helmet  –  Bad News
# 24 Bush  –  Greedy Fly - Remastered
# 25 Soundgarden  –  Burden In My Hand
# 26 The Smashing Pumpkins  –  Zero - Remastered 2012
# 27 Placebo  –  Brick Shithouse
# 28 The Smashing Pumpkins  –  Bodies - Remastered 2012
# 29 Lacuna Coil  –  Enjoy the Silence - cover version
# 30 Marilyn Manson  –  Great Big White World
# 31 Soundgarden  –  Pretty Noose
# 32 Soundgarden  –  Blow Up The Outside World
# 33 The Smashing Pumpkins  –  Here Is No Why - Remastered 2012
# 34 System Of A Down  –  Aerials
# 35 Radiohead  –  Paranoid Android
# 36 Marilyn Manson  –  Coma White
# 37 Garbage  –  Push It
# 38 Xana  –  Manual de sobrevivência I

# %%
sp.search(q="Billie Eilish")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4i3rAwPw7Ln2YrKDusaWyT'},
#      'href': 'https://api.spotify.com/v1/albums/4i3rAwPw7Ln2YrKDusaWyT',
#      'id': '4i3rAwPw7Ln2YrKDusaWyT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f2248cf6dad1d6c062587249',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f2248cf6dad1d6c062587249',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f2248cf6dad1d6c062587249',
#        'width': 64}],
#      'name': 'everything i wanted',
#      'release_date': '2019-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4i3rAwPw7Ln2YrKDusaWyT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 245425,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71922577'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZCTVFBt2Brf31RLEnCkWJ'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZCTVFBt2Brf31RLEnCkWJ',
#     'id': '3ZCTVFBt2Brf31RLEnCkWJ',
#     'is_local': False,
#     'name': 'everything i wanted',
#     'popularity': 86,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2b4bbf9aeb9afe974db96b124c00d410de385e4e?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3ZCTVFBt2Brf31RLEnCkWJ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qAwMsiIjTzlmfAkXKvhVA'},
#        'href': 'https://api.spotify.com/v1/artists/2qAwMsiIjTzlmfAkXKvhVA',
#        'id': '2qAwMsiIjTzlmfAkXKvhVA',
#        'name': 'Armani White',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qAwMsiIjTzlmfAkXKvhVA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4MajX5vPeY4cX5pv6rf0sA'},
#      'href': 'https://api.spotify.com/v1/albums/4MajX5vPeY4cX5pv6rf0sA',
#      'id': '4MajX5vPeY4cX5pv6rf0sA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734f8799f23432ad98d522f0ec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024f8799f23432ad98d522f0ec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514f8799f23432ad98d522f0ec',
#        'width': 64}],
#      'name': 'BILLIE EILISH.',
#      'release_date': '2022-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4MajX5vPeY4cX5pv6rf0sA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qAwMsiIjTzlmfAkXKvhVA'},
#       'href': 'https://api.spotify.com/v1/artists/2qAwMsiIjTzlmfAkXKvhVA',
#       'id': '2qAwMsiIjTzlmfAkXKvhVA',
#       'name': 'Armani White',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qAwMsiIjTzlmfAkXKvhVA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 99282,
#     'explicit': True,
#     'external_ids': {'isrc': 'SGB502248062'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/27ZZdyTSQWI7Cug2d2PkqV'},
#     'href': 'https://api.spotify.com/v1/tracks/27ZZdyTSQWI7Cug2d2PkqV',
#     'id': '27ZZdyTSQWI7Cug2d2PkqV',
#     'is_local': False,
#     'name': 'BILLIE EILISH.',
#     'popularity': 89,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a2ed105397586cd7a7bc1cd2f011887b0848b9c5?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:27ZZdyTSQWI7Cug2d2PkqV'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#      'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#      'id': '0JGOiO34nwfUdDrD612dOp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#        'width': 64}],
#      'name': 'Happier Than Ever',
#      'release_date': '2021-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 298899,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72105936'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#     'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#     'id': '4RVwu0g32PAqgUiJoXsdF8',
#     'is_local': False,
#     'name': 'Happier Than Ever',
#     'popularity': 89,
#     'preview_url': 'https://p.scdn.co/mp3-preview/20a10ed1ec5ad22668edc467682141db898ba45b?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#        'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#        'id': '6LuN9FCkKOj5PcnpouEgny',
#        'name': 'Khalid',
#        'type': 'artist',
#        'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#      'href': 'https://api.spotify.com/v1/albums/2sBB17RXTamvj7Ncps15AK',
#      'id': '2sBB17RXTamvj7Ncps15AK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738a3f0a3ca7929dea23cd274c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518a3f0a3ca7929dea23cd274c',
#        'width': 64}],
#      'name': 'lovely (with Khalid)',
#      'release_date': '2018-04-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2sBB17RXTamvj7Ncps15AK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#       'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#       'id': '6LuN9FCkKOj5PcnpouEgny',
#       'name': 'Khalid',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 200185,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71804190'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4'},
#     'href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#     'id': '0u2P5u6lvoDfwTYjAADbn4',
#     'is_local': False,
#     'name': 'lovely (with Khalid)',
#     'popularity': 89,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3ebe867688f8f3c20f550fa2308e06b42791824f?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/25FGyvj0UnD6YYWLq0s9nl'},
#      'href': 'https://api.spotify.com/v1/albums/25FGyvj0UnD6YYWLq0s9nl',
#      'id': '25FGyvj0UnD6YYWLq0s9nl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734adbeb26299adca766cec2c5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024adbeb26299adca766cec2c5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514adbeb26299adca766cec2c5',
#        'width': 64}],
#      'name': 'Bellyache',
#      'release_date': '2017-02-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:25FGyvj0UnD6YYWLq0s9nl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 179172,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71615103'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/51NFxnQvaosfDDutk0tams'},
#     'href': 'https://api.spotify.com/v1/tracks/51NFxnQvaosfDDutk0tams',
#     'id': '51NFxnQvaosfDDutk0tams',
#     'is_local': False,
#     'name': 'bellyache',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/51c59b1144fb831c56d1bef82b5947e384317178?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:51NFxnQvaosfDDutk0tams'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iyJ8i3eKbez8JXDbsHIdZ'},
#      'href': 'https://api.spotify.com/v1/albums/4iyJ8i3eKbez8JXDbsHIdZ',
#      'id': '4iyJ8i3eKbez8JXDbsHIdZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e0f2af91be409aad81bba98c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e0f2af91be409aad81bba98c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e0f2af91be409aad81bba98c',
#        'width': 64}],
#      'name': 'Bored',
#      'release_date': '2017-03-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4iyJ8i3eKbez8JXDbsHIdZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 180933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71702756'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/04sN26COy28wTXYj3dMoiZ'},
#     'href': 'https://api.spotify.com/v1/tracks/04sN26COy28wTXYj3dMoiZ',
#     'id': '04sN26COy28wTXYj3dMoiZ',
#     'is_local': False,
#     'name': 'Bored',
#     'popularity': 86,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0ceedcdbb60c7dd09e8ed303a4168b36ca5948a3?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:04sN26COy28wTXYj3dMoiZ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1OYhPeuiXfEPi8jIcbG7A4'},
#      'href': 'https://api.spotify.com/v1/albums/1OYhPeuiXfEPi8jIcbG7A4',
#      'id': '1OYhPeuiXfEPi8jIcbG7A4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273635a2be461f1ede3c3fcc6fc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02635a2be461f1ede3c3fcc6fc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851635a2be461f1ede3c3fcc6fc',
#        'width': 64}],
#      'name': 'Halloween & Alternative',
#      'release_date': '2022-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:1OYhPeuiXfEPi8jIcbG7A4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 193143,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900770'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7tWbogz6sIIV6FDcbxkEKw'},
#     'href': 'https://api.spotify.com/v1/tracks/7tWbogz6sIIV6FDcbxkEKw',
#     'id': '7tWbogz6sIIV6FDcbxkEKw',
#     'is_local': False,
#     'name': 'bury a friend',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7fbcb8fb5c7bd6b52f4e2dc16e3f58791d75e0a8?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7tWbogz6sIIV6FDcbxkEKw'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'CH',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'HK',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'ME',
#       'MK',
#       'MT',
#       'MY',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PH',
#       'PL',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'VN',
#       'XK',
#       'ZA',
#       'CM',
#       'DZ',
#       'GB',
#       'IE',
#       'MA',
#       'NG',
#       'PT',
#       'TN',
#       'CI',
#       'GH',
#       'IS',
#       'SN',
#       'AR',
#       'BR',
#       'CL',
#       'PY',
#       'UY',
#       'BO',
#       'CA',
#       'CW',
#       'DO',
#       'TT',
#       'US',
#       'VE',
#       'CO',
#       'EC',
#       'MX',
#       'PA',
#       'PE',
#       'CR',
#       'GT',
#       'HN',
#       'NI',
#       'SV'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/15nluFVjGIdG3wRNIlPIbk'},
#      'href': 'https://api.spotify.com/v1/albums/15nluFVjGIdG3wRNIlPIbk',
#      'id': '15nluFVjGIdG3wRNIlPIbk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731d8a1f38d4c9f43f2e91387d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021d8a1f38d4c9f43f2e91387d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511d8a1f38d4c9f43f2e91387d',
#        'width': 64}],
#      'name': 'Twisted Halloween Hits',
#      'release_date': '2022-10-19',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:15nluFVjGIdG3wRNIlPIbk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AE',
#      'AL',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'HK',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'ME',
#      'MK',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PH',
#      'PL',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'VN',
#      'XK',
#      'ZA',
#      'CM',
#      'DZ',
#      'GB',
#      'IE',
#      'MA',
#      'NG',
#      'PT',
#      'TN',
#      'CI',
#      'GH',
#      'IS',
#      'SN',
#      'AR',
#      'BR',
#      'CL',
#      'PY',
#      'UY',
#      'BO',
#      'CA',
#      'CW',
#      'DO',
#      'TT',
#      'US',
#      'VE',
#      'CO',
#      'EC',
#      'MX',
#      'PA',
#      'PE',
#      'CR',
#      'GT',
#      'HN',
#      'NI',
#      'SV'],
#     'disc_number': 1,
#     'duration_ms': 168839,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900766'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5olaF84x7e8jKLmLsm4aA4'},
#     'href': 'https://api.spotify.com/v1/tracks/5olaF84x7e8jKLmLsm4aA4',
#     'id': '5olaF84x7e8jKLmLsm4aA4',
#     'is_local': False,
#     'name': 'all the good girls go to hell',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/602943a3290edb8c5ebc98608138a7a98460b8a0?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5olaF84x7e8jKLmLsm4aA4'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'CH',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GR',
#       'HK',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'ME',
#       'MK',
#       'MT',
#       'MY',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PH',
#       'PL',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'VN',
#       'XK',
#       'ZA',
#       'CM',
#       'DZ',
#       'GB',
#       'IE',
#       'MA',
#       'NG',
#       'PT',
#       'TN',
#       'CI',
#       'GH',
#       'IS',
#       'SN',
#       'AR',
#       'BR',
#       'CL',
#       'PY',
#       'UY',
#       'BO',
#       'CA',
#       'CW',
#       'DO',
#       'TT',
#       'US',
#       'VE',
#       'CO',
#       'EC',
#       'MX',
#       'PA',
#       'PE',
#       'CR',
#       'GT',
#       'HN',
#       'NI',
#       'SV'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6R2jMboG4LzI7tMyqDihJo'},
#      'href': 'https://api.spotify.com/v1/albums/6R2jMboG4LzI7tMyqDihJo',
#      'id': '6R2jMboG4LzI7tMyqDihJo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b5d5a7d10b510f0b1b56bbe4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b5d5a7d10b510f0b1b56bbe4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b5d5a7d10b510f0b1b56bbe4',
#        'width': 64}],
#      'name': "pov: it's 2021",
#      'release_date': '2022-10-19',
#      'release_date_precision': 'day',
#      'total_tracks': 61,
#      'type': 'album',
#      'uri': 'spotify:album:6R2jMboG4LzI7tMyqDihJo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AE',
#      'AL',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GR',
#      'HK',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'ME',
#      'MK',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PH',
#      'PL',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'VN',
#      'XK',
#      'ZA',
#      'CM',
#      'DZ',
#      'GB',
#      'IE',
#      'MA',
#      'NG',
#      'PT',
#      'TN',
#      'CI',
#      'GH',
#      'IS',
#      'SN',
#      'AR',
#      'BR',
#      'CL',
#      'PY',
#      'UY',
#      'BO',
#      'CA',
#      'CW',
#      'DO',
#      'TT',
#      'US',
#      'VE',
#      'CO',
#      'EC',
#      'MX',
#      'PA',
#      'PE',
#      'CR',
#      'GT',
#      'HN',
#      'NI',
#      'SV'],
#     'disc_number': 1,
#     'duration_ms': 298899,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72105936'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IYIEqOfxaZU7J7MrR1cFi'},
#     'href': 'https://api.spotify.com/v1/tracks/5IYIEqOfxaZU7J7MrR1cFi',
#     'id': '5IYIEqOfxaZU7J7MrR1cFi',
#     'is_local': False,
#     'name': 'Happier Than Ever',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/04e368682513f285fc11e9486f0c985bb67544bc?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5IYIEqOfxaZU7J7MrR1cFi'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3enPdhM79GbVIjvFafj9b1'},
#      'href': 'https://api.spotify.com/v1/albums/3enPdhM79GbVIjvFafj9b1',
#      'id': '3enPdhM79GbVIjvFafj9b1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e579433745cbd04d74e11db1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e579433745cbd04d74e11db1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e579433745cbd04d74e11db1',
#        'width': 64}],
#      'name': 'Workout Pop Hits 2023',
#      'release_date': '2022-10-11',
#      'release_date_precision': 'day',
#      'total_tracks': 29,
#      'type': 'album',
#      'uri': 'spotify:album:3enPdhM79GbVIjvFafj9b1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6nKf92bFtbpxltAhi598JL'},
#     'href': 'https://api.spotify.com/v1/tracks/6nKf92bFtbpxltAhi598JL',
#     'id': '6nKf92bFtbpxltAhi598JL',
#     'is_local': False,
#     'name': 'bad guy',
#     'popularity': 3,
#     'preview_url': 'https://p.scdn.co/mp3-preview/403a89f6864cba3e820f54b6ce80452468646204?cid=dbe5d7f6592b42269cf87f9a888c8195',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:6nKf92bFtbpxltAhi598JL'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 3327}}
